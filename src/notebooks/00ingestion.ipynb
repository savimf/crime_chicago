# %% [markdown]
# # Chicago Risk Classification

# %%
import pandas as pd
from sodapy import Socrata

# %%
from sys import path

path.insert(0, '../modules')

import utils as f
import params_cfg as pc
import visuals

# %load_ext autoreload
# %autoreload 2

# %%
brz_path = pc.BRZ_PATH

# %% [markdown]
# ## Police Stations

# %%
client = Socrata('data.cityofchicago.org', None)

results_stations = client.get(
    'z8bn-74gv',
    select="district, district_name, latitude, longitude"
)
print('Download complete!')

df_stations = pd.DataFrame.from_records(results_stations)
df_stations = f.rm_columns(df_stations)

print('POLICE STATIONS complete!')

df_stations.head()
# Out:
# Download complete!
# POLICE STATIONS complete!
#        district district_name     latitude     longitude
# 0  Headquarters  Headquarters  41.83070169  -87.62339535
# 1            18    Near North  41.90324165  -87.64335214
# 2            19     Town Hall  41.94740046  -87.65151202
# 3            20       Lincoln  41.97954951  -87.69284451
# 4            22   Morgan Park  41.69143478  -87.66852039

# %%
df_stations.to_csv(f'{brz_path}/df_stations.csv', index=False)

# %% [markdown]
# ## Community Area

# %%
results_comm = client.get(
    'igwz-8jzy',
    select='the_geom, area_numbe, community, shape_area, shape_len'
)
print('Download complete!')

df_comm = pd.DataFrame.from_records(results_comm)
df_comm = f.rm_columns(df_comm)

print('COMMUNITY AREAS complete!')

df_comm.head()
# Out:
# Download complete!
# COMMUNITY AREAS complete!
#                                             the_geom area_numbe  \
# 0  {'type': 'MultiPolygon', 'coordinates': [[[[-8...          1
# 1  {'type': 'MultiPolygon', 'coordinates': [[[[-8...          2
# 2  {'type': 'MultiPolygon', 'coordinates': [[[[-8...          3
# 3  {'type': 'MultiPolygon', 'coordinates': [[[[-8...          4
# 4  {'type': 'MultiPolygon', 'coordinates': [[[[-8...          5
#
#         community     shape_area      shape_len
# 0     ROGERS PARK  51259902.4506  34052.3975757
# 1      WEST RIDGE  98429094.8621  43020.6894583
# 2          UPTOWN  65095642.7289  46972.7945549
# 3  LINCOLN SQUARE  71352328.2399  36624.6030848
# 4    NORTH CENTER    57054167.85  31391.6697542

# %%
df_comm.to_csv(f'{brz_path}/df_comm.csv', index=False)

# %% [markdown]
# ## Census

# %%
results_census = client.get(
    'kn9c-c2s2',
    select="""
        ca, percent_of_housing_crowded,
        percent_households_below_poverty,
        percent_aged_16_unemployed,
        percent_aged_25_without_high_school_diploma,
        percent_aged_under_18_or_over_64,
        per_capita_income_,
        hardship_index
    """
)
print('Download complete!')

df_census = pd.DataFrame.from_records(results_census)
df_census = f.rm_columns(df_census)

print('CENSUS complete!')

df_census.head()
# Out:
# Download complete!
# CENSUS complete!
#   ca percent_of_housing_crowded percent_households_below_poverty  \
# 0  1                        7.7                             23.6
# 1  2                        7.8                             17.2
# 2  3                        3.8                               24
# 3  4                        3.4                             10.9
# 4  5                        0.3                              7.5
#
#   percent_aged_16_unemployed percent_aged_25_without_high_school_diploma  \
# 0                        8.7                                        18.2
# 1                        8.8                                        20.8
# 2                        8.9                                        11.8
# 3                        8.2                                        13.4
# 4                        5.2                                         4.5
#
#   percent_aged_under_18_or_over_64 per_capita_income_ hardship_index
# 0                             27.5              23939             39
# 1                             38.5              23040             46
# 2                             22.2              35787             20
# 3                             25.5              37524             17
# 4                             26.2              57123              6

# %%
df_census.to_csv(f'{brz_path}/df_census.csv', index=False)

# %% [markdown]
# ## Districts

# %%
results_districts = client.get(
    '24zt-jpfn',
    select='the_geom, dist_num'
)
print(f'Download complete!')

df_districts = pd.DataFrame.from_records(results_districts)
df_districts = f.rm_columns(df_districts)

print('DISTRICTS complete!')

df_districts.head()
# Out:
# Download complete!
# DISTRICTS complete!
#                                             the_geom dist_num
# 0  {'type': 'MultiPolygon', 'coordinates': [[[[-8...       17
# 1  {'type': 'MultiPolygon', 'coordinates': [[[[-8...       20
# 2  {'type': 'MultiPolygon', 'coordinates': [[[[-8...       31
# 3  {'type': 'MultiPolygon', 'coordinates': [[[[-8...       31
# 4  {'type': 'MultiPolygon', 'coordinates': [[[[-8...       19

# %%
df_districts.to_csv(f'{brz_path}/df_districts.csv', index=False)

# %% [markdown]
# ## Crimes

# %%
results_crime = client.get(
    'ijzp-q8t2',
    select="""
            id, date, primary_type,
            arrest, domestic,
            district, community_area,
            latitude, longitude
        """,
    where=f"date >= '2022-01-01'",
    limit=1_000_000
)
print('Download complete!')

df_crime = pd.DataFrame.from_records(results_crime)
df_crime = f.rm_columns(df_crime)

print('CRIMES complete!')

df_crime.head()
# Out:
# Download complete!
# CRIMES complete!
#          id                     date                primary_type  arrest  \
# 0  13344078  2022-01-01T00:00:00.000                 SEX OFFENSE   False
# 1  13221894  2022-01-01T00:00:00.000          DECEPTIVE PRACTICE   False
# 2  13435498  2022-01-01T00:00:00.000                     BATTERY   False
# 3  13140498  2022-01-01T00:00:00.000     CRIMINAL SEXUAL ASSAULT   False
# 4  13353204  2022-01-01T00:00:00.000  OFFENSE INVOLVING CHILDREN   False
#
#    domestic district community_area      latitude      longitude
# 0     False      022             75  41.684023827  -87.680913765
# 1     False      011             23           NaN            NaN
# 2      True      016             11           NaN            NaN
# 3     False      019              6           NaN            NaN
# 4      True      008             63           NaN            NaN

# %%
df_crime.to_csv(f'{brz_path}/df_crime.csv', index=False)
